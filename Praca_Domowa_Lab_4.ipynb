# %% [markdown]
# <a href="https://colab.research.google.com/github/MichalSien/Michal-Lab/blob/main/Praca_Domowa_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function

import matplotlib.pyplot as plt
import numpy as np





import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.optimizers import RMSprop, Adam, Adadelta
from keras.preprocessing.image import ImageDataGenerator

from keras.utils.vis_utils import plot_model
from IPython.display import Image 

from keras.callbacks import EarlyStopping

batch_size = 128
num_classes = 10
epochs = 200

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train0), (x_test, y_test0) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

! pip install optuna


x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train0, num_classes)
y_test = keras.utils.to_categorical(y_test0, num_classes)

N_TRAIN_EXAMPLES=500 #3000
N_TEST_EXAMPLES=10000

x_train=x_train[:N_TRAIN_EXAMPLES]
x_test=x_test[:N_TEST_EXAMPLES]
y_train=y_train[:N_TRAIN_EXAMPLES]
y_test=y_test[:N_TEST_EXAMPLES]

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Collecting optuna
#   Downloading https://files.pythonhosted.org/packages/87/10/06b58f4120f26b603d905a594650440ea1fd74476b8b360dbf01e111469b/optuna-2.3.0.tar.gz (258kB)
#      |████████████████████████████████| 266kB 8.8MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting alembic
#   Downloading https://files.pythonhosted.org/packages/12/aa/c261dfd7f4ba6ce4701846a2689a46e2a172e012171de4378fc2926e3bf0/alembic-1.4.3-py2.py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 11.9MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from optuna) (1.0.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (20.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from optuna) (4.41.1)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from optuna) (1.19.4)
# Collecting cliff
#   Downloading https://files.pythonhosted.org/packages/8a/61/5b64d73b01c1218f55c894b5ec0fb89b32c6960b7f7b3ad9f5ac0c373b9d/cliff-3.5.0-py3-none-any.whl (81kB)
#      |████████████████████████████████| 81kB 9.5MB/s
# Collecting cmaes>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/8d/3c/06c76ec8b54b9b1fad7f35e903fd25010fe3e0d41bd94cea5e6f12e0d651/cmaes-0.7.0-py3-none-any.whl
# Collecting colorlog
#   Downloading https://files.pythonhosted.org/packages/4e/c8/c16d30bbed11a1722060014c246d124582d1f781b26f5859d8dacc3e08e1/colorlog-4.6.2-py2.py3-none-any.whl
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.3.20)
# Collecting python-editor>=0.3
#   Downloading https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (2.8.1)
# Collecting Mako
#   Downloading https://files.pythonhosted.org/packages/a6/37/0e706200d22172eb8fa17d68a7ae22dec7631a0a92266634fb518a88a5b2/Mako-1.1.3-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 1.3MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=20.0->optuna) (2.4.7)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/fb/48/69046506f6ac61c1eaa9a0d42d22d54673b69e176d30ca98e3f61513e980/pbr-5.5.1-py2.py3-none-any.whl (106kB)
#      |████████████████████████████████| 112kB 12.0MB/s
# Collecting PrettyTable<0.8,>=0.7.2
#   Downloading https://files.pythonhosted.org/packages/ef/30/4b0746848746ed5941f052479e7c23d2b56d174b82f4fd34a25e389831f5/prettytable-0.7.2.tar.bz2
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (1.15.0)
# Collecting stevedore>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/d4/49/b602307aeac3df3384ff1fcd05da9c0376c622a6c48bb5325f28ab165b57/stevedore-3.3.0-py3-none-any.whl (49kB)
#      |████████████████████████████████| 51kB 7.2MB/s
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (3.13)
# Collecting cmd2!=0.8.3,>=0.8.0
#   Downloading https://files.pythonhosted.org/packages/27/54/af6e2703f064485d717cb311d3f9440cd302a823ba6d80a020b59eae166d/cmd2-1.4.0-py3-none-any.whl (133kB)
#      |████████████████████████████████| 133kB 15.7MB/s
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic->optuna) (1.1.1)
# Requirement already satisfied: importlib-metadata>=1.7.0; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from stevedore>=2.0.1->cliff->optuna) (3.3.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (0.2.5)
# Collecting pyperclip>=1.6
#   Downloading https://files.pythonhosted.org/packages/6f/4c/0b1d507ad7e8bc31d690d04b4f475e74c2002d060f7994ce8c09612df707/pyperclip-1.8.1.tar.gz
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (20.3.0)
# Collecting colorama>=0.3.7
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=1.7.0; python_version < "3.8"->stevedore>=2.0.1->cliff->optuna) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=1.7.0; python_version < "3.8"->stevedore>=2.0.1->cliff->optuna) (3.7.4.3)
# Building wheels for collected packages: optuna
#   Building wheel for optuna (PEP 517) ... done
#   Created wheel for optuna: filename=optuna-2.3.0-cp36-none-any.whl size=359761 sha256=1c3945ace7a7a9c71233e4ba11239b892a62220c0243613f3ac9b72b5bfc32a4
#   Stored in directory: /root/.cache/pip/wheels/fa/91/19/64b0ec6b964f89c0695a9dc6db6f851d0b54c5381a5c9cadfb
# Successfully built optuna
# Building wheels for collected packages: PrettyTable, pyperclip
#   Building wheel for PrettyTable (setup.py) ... done
#   Created wheel for PrettyTable: filename=prettytable-0.7.2-cp36-none-any.whl size=13702 sha256=54a50c0f59442de53bf2ea0cf88b2c77c1856b041f01e37adb3c1a2398bb779c
#   Stored in directory: /root/.cache/pip/wheels/80/34/1c/3967380d9676d162cb59513bd9dc862d0584e045a162095606
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.1-cp36-none-any.whl size=11120 sha256=34625dc34999621b99667b9b16d297448611db4c91383ff4febef3165e9c31cf
#   Stored in directory: /root/.cache/pip/wheels/44/10/3a/c830e9bb3db2c93274ea1f213a41fabde0d8cf3794251fad0c
# Successfully built PrettyTable pyperclip
# Installing collected packages: python-editor, Mako, alembic, pbr, PrettyTable, stevedore, pyperclip, colorama, cmd2, cliff, cmaes, colorlog, optuna
#   Found existing installation: prettytable 2.0.0
#     Uninstalling prettytable-2.0.0:
#       Successfully uninstalled prettytable-2.0.0
# Successfully installed Mako-1.1.3 PrettyTable-0.7.2 alembic-1.4.3 cliff-3.5.0 cmaes-0.7.0 cmd2-1.4.0 colorama-0.4.4 colorlog-4.6.2 optuna-2.3.0 pbr-5.5.1 pyperclip-1.8.1 python-editor-1.0.4 stevedore-3.3.0
# 500 train samples
# 10000 test samples

# %%
#visualize the digits

fig = plt.figure(figsize=(10, 10))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(100):
    ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
    ax.imshow(x_train[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')
    # label the image with the target value
    ax.text(0, 7, str(y_train0[i]))

# %%
# set up image augmentation
datagen = ImageDataGenerator( 
    rotation_range=30,
    horizontal_flip=False,
    vertical_flip=False,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.15
    )
datagen.fit(x_train)

# %%
# see example augmentation images

fig = plt.figure(figsize=(12, 12))
for X_batch, y_batch in datagen.flow(x_train, y_train, batch_size=9):
    for i in range(0, 9):
         plt.subplot(330 + 1 + i)
         plt.imshow(X_batch[i].reshape(img_rows,img_cols),cmap=plt.cm.binary, interpolation='nearest')
         plt.axis('off')
    plt.show()
    break

# %%
# see example augmentation images
fig = plt.figure(figsize=(12, 12))

for i in range(0, 25):
    for X_batch, y_batch in datagen.flow(x_train[4:7], y_train[4:7], batch_size=1, shuffle=False):
         plt.subplot(5,5,i+1)
         plt.imshow(X_batch[0].reshape(img_rows,img_cols),cmap=plt.cm.binary, interpolation='nearest')
         plt.axis('off')
         break

plt.show()

# %%
# Our old fully connected (dense) network
#model = Sequential()
#model.add(Dense(512, activation='relu', input_shape=(784,)))
#model.add(Dropout(0.2))
#model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.2))
#model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.2))
#model.add(Dense(num_classes, activation='softmax'))

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))



model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               131200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 225,162
# Trainable params: 225,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
Image('model_plot.png')

# %%
model.compile(loss='categorical_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])

es = EarlyStopping(monitor = 'val_accuracy', patience =12, verbose=1)

history = model.fit(datagen.flow(x_train, y_train,batch_size=batch_size),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test),
                    callbacks = [es])
# Out:
# Epoch 1/200
# 4/4 [==============================] - 8s 2s/step - loss: 2.3062 - accuracy: 0.0900 - val_loss: 2.2770 - val_accuracy: 0.1304
# Epoch 2/200
# 4/4 [==============================] - 7s 2s/step - loss: 2.2790 - accuracy: 0.1636 - val_loss: 2.2299 - val_accuracy: 0.3801
# Epoch 3/200
# 4/4 [==============================] - 7s 2s/step - loss: 2.2444 - accuracy: 0.1755 - val_loss: 2.0934 - val_accuracy: 0.4768
# Epoch 4/200
# 4/4 [==============================] - 7s 2s/step - loss: 2.1388 - accuracy: 0.2839 - val_loss: 1.8572 - val_accuracy: 0.3907
# Epoch 5/200
# 4/4 [==============================] - 7s 2s/step - loss: 2.0416 - accuracy: 0.3052 - val_loss: 1.6058 - val_accuracy: 0.5302
# Epoch 6/200
# 4/4 [==============================] - 7s 2s/step - loss: 1.8735 - accuracy: 0.3253 - val_loss: 1.3579 - val_accuracy: 0.5968
# Epoch 7/200
# 4/4 [==============================] - 7s 2s/step - loss: 1.7548 - accuracy: 0.3861 - val_loss: 1.1688 - val_accuracy: 0.6804
# Epoch 8/200
# 4/4 [==============================] - 7s 2s/step - loss: 1.6212 - accuracy: 0.4481 - val_loss: 1.0307 - val_accuracy: 0.6951
# Epoch 9/200
# 4/4 [==============================] - 7s 2s/step - loss: 1.5347 - accuracy: 0.4471 - val_loss: 0.9250 - val_accuracy: 0.7338
# Epoch 10/200
# 4/4 [==============================] - 7s 2s/step - loss: 1.4146 - accuracy: 0.5407 - val_loss: 0.8017 - val_accuracy: 0.7567
# Epoch 11/200
# 4/4 [==============================] - 7s 2s/step - loss: 1.3183 - accuracy: 0.5453 - val_loss: 0.6733 - val_accuracy: 0.8142
# Epoch 12/200
# 4/4 [==============================] - 7s 2s/step - loss: 1.2327 - accuracy: 0.5808 - val_loss: 0.6019 - val_accuracy: 0.8250
# Epoch 13/200
# 4/4 [==============================] - 7s 2s/step - loss: 1.2166 - accuracy: 0.6087 - val_loss: 0.5214 - val_accuracy: 0.8487
# Epoch 14/200
# 4/4 [==============================] - 7s 2s/step - loss: 1.0967 - accuracy: 0.6381 - val_loss: 0.4745 - val_accuracy: 0.8578
# Epoch 15/200
# 4/4 [==============================] - 7s 2s/step - loss: 1.1979 - accuracy: 0.6305 - val_loss: 0.4551 - val_accuracy: 0.8657
# Epoch 16/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.9254 - accuracy: 0.6751 - val_loss: 0.3907 - val_accuracy: 0.8871
# Epoch 17/200
# 4/4 [==============================] - 7s 2s/step - loss: 1.0007 - accuracy: 0.6520 - val_loss: 0.3684 - val_accuracy: 0.8900
# Epoch 18/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.9014 - accuracy: 0.7159 - val_loss: 0.3554 - val_accuracy: 0.8929
# Epoch 19/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.9043 - accuracy: 0.7174 - val_loss: 0.3526 - val_accuracy: 0.8911
# Epoch 20/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.8466 - accuracy: 0.7527 - val_loss: 0.3151 - val_accuracy: 0.9027
# Epoch 21/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.7671 - accuracy: 0.7479 - val_loss: 0.2621 - val_accuracy: 0.9167
# Epoch 22/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.7582 - accuracy: 0.7550 - val_loss: 0.2783 - val_accuracy: 0.9126
# Epoch 23/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.8019 - accuracy: 0.7402 - val_loss: 0.2662 - val_accuracy: 0.9146
# Epoch 24/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.7536 - accuracy: 0.7400 - val_loss: 0.2567 - val_accuracy: 0.9181
# Epoch 25/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.7313 - accuracy: 0.7525 - val_loss: 0.2466 - val_accuracy: 0.9212
# Epoch 26/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.7832 - accuracy: 0.7572 - val_loss: 0.2147 - val_accuracy: 0.9340
# Epoch 27/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.6467 - accuracy: 0.7939 - val_loss: 0.2068 - val_accuracy: 0.9349
# Epoch 28/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.6220 - accuracy: 0.7961 - val_loss: 0.1979 - val_accuracy: 0.9357
# Epoch 29/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.6799 - accuracy: 0.7817 - val_loss: 0.2040 - val_accuracy: 0.9346
# Epoch 30/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.5620 - accuracy: 0.8254 - val_loss: 0.2121 - val_accuracy: 0.9312
# Epoch 31/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.6523 - accuracy: 0.8030 - val_loss: 0.2121 - val_accuracy: 0.9293
# Epoch 32/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.6022 - accuracy: 0.8098 - val_loss: 0.2150 - val_accuracy: 0.9335
# Epoch 33/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.5673 - accuracy: 0.8209 - val_loss: 0.1803 - val_accuracy: 0.9440
# Epoch 34/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.6241 - accuracy: 0.8021 - val_loss: 0.1760 - val_accuracy: 0.9403
# Epoch 35/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.5624 - accuracy: 0.8034 - val_loss: 0.1732 - val_accuracy: 0.9401
# Epoch 36/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.5353 - accuracy: 0.8271 - val_loss: 0.1610 - val_accuracy: 0.9465
# Epoch 37/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.4961 - accuracy: 0.8587 - val_loss: 0.1571 - val_accuracy: 0.9467
# Epoch 38/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.5104 - accuracy: 0.8452 - val_loss: 0.1496 - val_accuracy: 0.9504
# Epoch 39/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.4948 - accuracy: 0.8504 - val_loss: 0.1488 - val_accuracy: 0.9507
# Epoch 40/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.5049 - accuracy: 0.8271 - val_loss: 0.1774 - val_accuracy: 0.9425
# Epoch 41/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.4966 - accuracy: 0.8468 - val_loss: 0.1599 - val_accuracy: 0.9466
# Epoch 42/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.5048 - accuracy: 0.8388 - val_loss: 0.1635 - val_accuracy: 0.9445
# Epoch 43/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.4302 - accuracy: 0.8431 - val_loss: 0.1635 - val_accuracy: 0.9447
# Epoch 44/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.4330 - accuracy: 0.8769 - val_loss: 0.1538 - val_accuracy: 0.9492
# Epoch 45/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.4168 - accuracy: 0.8481 - val_loss: 0.1282 - val_accuracy: 0.9578
# Epoch 46/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.4380 - accuracy: 0.8566 - val_loss: 0.1364 - val_accuracy: 0.9557
# Epoch 47/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.3850 - accuracy: 0.8788 - val_loss: 0.1234 - val_accuracy: 0.9604
# Epoch 48/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.4366 - accuracy: 0.8650 - val_loss: 0.1328 - val_accuracy: 0.9568
# Epoch 49/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.3604 - accuracy: 0.8698 - val_loss: 0.1344 - val_accuracy: 0.9539
# Epoch 50/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.3845 - accuracy: 0.8861 - val_loss: 0.1232 - val_accuracy: 0.9588
# Epoch 51/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.3486 - accuracy: 0.8881 - val_loss: 0.1136 - val_accuracy: 0.9625
# Epoch 52/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.4356 - accuracy: 0.8613 - val_loss: 0.1137 - val_accuracy: 0.9651
# Epoch 53/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.4172 - accuracy: 0.8632 - val_loss: 0.1073 - val_accuracy: 0.9639
# Epoch 54/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.3721 - accuracy: 0.8725 - val_loss: 0.1120 - val_accuracy: 0.9637
# Epoch 55/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.3382 - accuracy: 0.8926 - val_loss: 0.1131 - val_accuracy: 0.9617
# Epoch 56/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.3925 - accuracy: 0.8758 - val_loss: 0.1178 - val_accuracy: 0.9616
# Epoch 57/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.3478 - accuracy: 0.8954 - val_loss: 0.1207 - val_accuracy: 0.9616
# Epoch 58/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.3793 - accuracy: 0.9071 - val_loss: 0.1193 - val_accuracy: 0.9603
# Epoch 59/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.4119 - accuracy: 0.8722 - val_loss: 0.1165 - val_accuracy: 0.9612
# Epoch 60/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.2960 - accuracy: 0.8961 - val_loss: 0.1094 - val_accuracy: 0.9630
# Epoch 61/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.3582 - accuracy: 0.8714 - val_loss: 0.1083 - val_accuracy: 0.9644
# Epoch 62/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.3443 - accuracy: 0.8815 - val_loss: 0.1138 - val_accuracy: 0.9624
# Epoch 63/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.3230 - accuracy: 0.8965 - val_loss: 0.1047 - val_accuracy: 0.9657
# Epoch 64/200
# 4/4 [==============================] - 7s 2s/step - loss: 0.2884 - accuracy: 0.9085 - val_loss: 0.1016 - val_accuracy: 0.9665
# Epoch 65/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2948 - accuracy: 0.8958

# %%
# Plots for training and testing process: loss and accuracy

n_epochs = len(history.history['loss'])

plt.figure(0)
plt.plot(history.history['accuracy'],'r')
plt.plot(history.history['val_accuracy'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Cat_Accuracy vs Validation Cat_Accuracy")
plt.legend(['train','validation'])

# %%
plt.figure(1)
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
plt.show()

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
# evaluate loaded model
scores_train = model.evaluate(x_train, y_train, verbose=0)
scores_test  = model.evaluate(x_test,  y_test,  verbose=0)

print("Accuracy Train: %.2f%% , Test: %.2f%% " % (scores_train[1]*100, scores_test[1]*100 ))

# %%
# Confusion matrix result

from sklearn.metrics import classification_report, confusion_matrix
Y_pred = model.predict(x_test, verbose=2)

y_pred = np.argmax(Y_pred, axis=1)

y_test2 = np.argmax(y_test, axis=1)



#confusion matrix
cm = confusion_matrix(np.argmax(y_test,axis=1),y_pred)
print(cm)

# %%
# Visualizing of confusion matrix
import seaborn as sn
import pandas  as pd


df_cm = pd.DataFrame(cm, range(10),range(10))
#                     range(num_classes),
#                  range(num_classes))
#plt.figure(figsize = (10,7))
plt.figure(2,figsize = (15,15) )
sn.set(font_scale=1.4) #for label size
sn.heatmap(df_cm, annot=True,annot_kws={"size": 12})# font size
plt.show()

# %%
# use the model to predict the labels of the test data
predicted = model.predict(x_test)
expected = y_test0



# Plot the prediction
fig = plt.figure(figsize=(20, 20))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)


# plot the digits: each image is 28x28 pixels
for i in range(400):
    ax = fig.add_subplot(20, 20, i + 1, xticks=[], yticks=[])
    ax.imshow(x_test[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')

    # label the image with the target value
    if np.argmax(predicted[i]) == expected[i]:
        ax.text(0, 7, str(expected[i])+" "+str(np.argmax(predicted[i])), color='green')
    else:
        ax.text(0, 7, str(expected[i])+" "+str(np.argmax(predicted[i])), color='red')

# %%
# Creates the graph.png file

! pip3 install keras-visualizer
from keras_visualizer import visualizer  

#create the graph.png image
visualizer(model=model, view=True, format='png', filename='graph')

#show the graph
import matplotlib.image as mpimg
img = mpimg.imread('graph.png')
imgplot = plt.imshow(img,)
plt.show()
